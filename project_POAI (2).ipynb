# %%
#importing importand library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#calling the csv 
df= pd.read_csv("C:/National college/programming of AI/project/unemployment analysis.csv")
# cheaking the csv
df.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %% [markdown]
# # data characteristics

# %%
# data population
total_records = len(df)
unique_records = len(df.drop_duplicates())

# here Data A􀆩ributes
num_arributes = len(df.columns)
arribute_names = list(df.columns)
print("total record",total_records)
print("unique record",unique_records)
print("num arributes ",num_arributes)
print("arribute names",arribute_names)

df.describe()
df.info()
# Out:
# total record 235
# unique record 235
# num arributes  33
# arribute names ['Country Name', 'Country Code', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  235 non-null    object
#  1   Country Code  235 non-null    object
#  2   1991          235 non-null    float64
#  3   1992          235 non-null    float64
#  4   1993          235 non-null    float64
#  5   1994          235 non-null    float64
#  6   1995          235 non-null    float64
#  7   1996          235 non-null    float64
#  8   1997          235 non-null    float64
# ...

# %%
# checking null values
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning and Transformation

# %%
df = df.drop('Country Code', axis = 1)

# %%
df = df.set_index('Country Name')
df = df.T
df.head(10)
# Out:
# Country Name  Africa Eastern and Southern  Afghanistan  \
# 1991                                 7.80        10.65
# 1992                                 7.84        10.82
# 1993                                 7.85        10.72
# 1994                                 7.84        10.73
# 1995                                 7.83        11.18
# 1996                                 7.84        10.96
# 1997                                 7.86        10.78
# 1998                                 7.81        10.80
# 1999                                 7.79        10.81
# 2000                                 7.72        10.81
#
# Country Name  Africa Western and Central  Angola  Albania  Arab World  \
# 1991                                4.42    4.21    10.31       11.62
# 1992                                4.53    4.21    30.01       12.12
# 1993                                4.55    4.23    25.26       12.86
# 1994                                4.54    4.16    20.84       12.95
# ...

# %% [markdown]
# # Grouping by Regions

# %%
groups = ['Africa Eastern and Southern', 
        'Africa Western and Central', 'Arab World',
        'Central Europe and the Baltics', 
        'Caribbean small states',
        'East Asia & Pacific (excluding high income)',
        'Early-demographic dividend', 'East Asia & Pacific',
        'Europe & Central Asia (excluding high income)',
        'Europe & Central Asia', 
        'Euro area',
        'European Union', 'Fragile and conflict affected situations',
        'High income',
        'Heavily indebted poor countries (HIPC)', 
        'IBRD only', 'IDA & IBRD total', 'IDA total',
        'IDA blend', 'IDA only', 
        'Latin America & Caribbean (excluding high income)', 
        'Latin America & Caribbean',
        'Least developed countries: UN classification', 'Low income',
         'Lower middle income', 'Low & middle income',
         'Late-demographic dividend',  'Middle East & North Africa', 
        'Middle income', 
        'Middle East & North Africa (excluding high income)', 
        'OECD members', 'Other small states',
        'Pre-demographic dividend', 'Pacific island small states',
        'Post-demographic dividend',
        'Sub-Saharan Africa (excluding high income)', 
        'Sub-Saharan Africa', 'Small states',
        'East Asia & Pacific (IDA & IBRD countries)',
        'Europe & Central Asia (IDA & IBRD countries)', 
        'Latin America & the Caribbean (IDA & IBRD countries)',
         'Middle East & North Africa (IDA & IBRD countries)',
        'South Asia (IDA & IBRD)',
        'Sub-Saharan Africa (IDA & IBRD countries)',
        'Upper middle income', 'World']

df_c = df.drop(groups, axis = 1)

# %% [markdown]
# # Further Grouping by Geography

# %%
#Purely based on geography (no differentiation of low/high income status)
sgroup = ['Africa Eastern and Southern', 
        'Africa Western and Central', 
        'Central Europe and the Baltics', 
        'Latin America & Caribbean',
        'Caribbean small states',
        'North America',
        'Sub-Saharan Africa','European Union',
        'Europe & Central Asia',
        'East Asia & Pacific',
        'Sub-Saharan Africa',
        'Middle East & North Africa']
df_g = df[sgroup]
df_g.head()
# Out:
# Country Name  Africa Eastern and Southern  Africa Western and Central  \
# 1991                                 7.80                        4.42
# 1992                                 7.84                        4.53
# 1993                                 7.85                        4.55
# 1994                                 7.84                        4.54
# 1995                                 7.83                        4.53
#
# Country Name  Central Europe and the Baltics  Latin America & Caribbean  \
# 1991                                    9.25                       6.12
# 1992                                   10.13                       6.08
# 1993                                   11.53                       6.09
# 1994                                   11.37                       6.55
# 1995                                   10.84                       7.72
#
# Country Name  Caribbean small states  North America  Sub-Saharan Africa  \
# ...

# %% [markdown]
# # Grouping by Income

# %%
#Based on income status
income = ['High income', 'Low income', 'Lower middle income', 
          'Low & middle income', 'Upper middle income',
          'Heavily indebted poor countries (HIPC)']
df_in = df[income]

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (12,4));
df['World'].plot(kind = 'bar')
plt.xlabel('Year');
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate');
plt.title('Unemployment rate for the world from 1991-2021');

# %%
plt.figure(figsize = (12,6));
sns.lineplot(df[['European Union', 'North America','Latin America & Caribbean', 'Africa Eastern and Southern',
                      'Africa Western and Central',  'Middle East & North Africa','East Asia & Pacific']])
plt.xlabel('Year');
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate');
plt.title('Unemployment rate for all regions from 1991-2021');
plt.legend(loc = 'upper right');

# %%
plt.figure(figsize = (12,6));
sns.lineplot(df[['Fragile and conflict affected situations',
                 'Least developed countries: UN classification',
                'Heavily indebted poor countries (HIPC)',
                'Lower middle income']])
plt.xlabel('Year');
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate');
plt.title('Unemployment rate for low income regions from 1991-2021');
plt.legend(loc = 'upper right');

# %%
plt.figure(figsize = (12,6));
sns.lineplot(df_in)
plt.xlabel('Year');
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate');
plt.title('Unemployment rate for different regions based on income status from 1991-2021');
plt.legend(loc = 'upper right');

# %%
plt.figure(figsize = (12,6));
sns.lineplot(data=df[['India', 'China', 'United Kingdom', 'United States']])
plt.xlabel('Year');
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate');
plt.title('Unemployment rate for selected countries from 1991-2021');
plt.legend(loc = 'upper right');

# %%
df_in_09  = df_in.loc['2009']
dfg_09 = df_g.loc['2009']

# %%
plt.figure(figsize = (16,6));
dfg_09.sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel('Year',fontsize = 14);
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate', fontsize = 14);
plt.title('Unemployment rate for all regions in 2009', fontsize=20);

# %%
plt.figure(figsize = (12,4));
df_in_09.sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel('Year', fontsize = 14);
plt.xticks(rotation=60)
plt.ylabel('Unemployment rate', fontsize = 14);
plt.title('Unemployment rate for all economies in 2009', fontsize = 20);

# %%
df_in_20  = df_in.loc['2020']
dfg_20 = df_g.loc['2020']
plt.figure(figsize = (16,6));
dfg_20.sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel('Year', fontsize = 14);
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate',fontsize = 14);
plt.title('Unemployment rate for all regions in 2020',fontsize = 20);

# %%
plt.figure(figsize = (10,4));
df_in_20.sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel('Year', fontsize = 14);
plt.xticks(rotation='vertical')
plt.ylabel('Unemployment rate', fontsize = 14);
plt.title('Unemployment rate for all economies in 2020', fontsize = 20);

# %%
df_fc = df[['China', 'European Union', 'United States']]
plt.figure(figsize = (15,5))
df_fc.plot();
plt.title('Unemployment in selected countries');

# %% [markdown]
# # Splitting the Data:

# %%
Ntest = 6
train = df_fc.iloc[:-Ntest]
test = df_fc.iloc[-Ntest:]

train_idx = df_fc.index <= train.index[-1]
test_idx = df_fc.index > train.index[-1]

#Defining a Plotting Function: 

def plot_fit_and_forecast(result, df_col, name):
    fig, ax = plt.subplots(figsize = (10,4))
    ax.plot(df_col, label = 'data')
    #plot the fitted curve on the train set
    train_pred = result.fittedvalues
    ax.plot(train.index, train_pred, color = 'green', label = 'in_sample fitted')
    
    #forecast the test set
    pred_result = result.get_forecast(Ntest)
    
    #calling conf_int() produces a dataframe with 2 columns: lower & upper values
    conf_int = pred_result.conf_int()
    lower, upper = conf_int['lower '+ name], conf_int['upper '+ name]
    forecast = pred_result.predicted_mean
    
    #plotting the forecasted values
    ax.plot(test.index, forecast, label = 'forecast')
    ax.set_xticklabels(labels = np.arange(1991, 2022, 1), rotation = 90)
    
    #create a shaded area in the plot with the confidence interval (alpha = transparency)
    ax.fill_between(test.index, lower, upper, color = 'blue', alpha = 0.2)
    ax.set_title('Unemployment forecast')
    ax.legend()

# %% [markdown]
# # Performing Augmented Dickey-Fuller Test:

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
def adf(x):
    res = adfuller(x)
    print("Test-statistic:", res[0])
    print("p-value:", res[1])
    if res[1] <0.05:
        print('Stationary')
    else:
        print('Non-stationary')

# %%
adf(df['China'])
# Out:
# Test-statistic: -2.3311948546050476
# p-value: 0.1621042676181339
# Non-stationary

# %% [markdown]
# # Plotting ACF and PACF:

# %%
fig,ax = plt.subplots(2,1, figsize=(8,6))
#p value in ARIMA(d,p,q)
plot_pacf(df['China'], lags = 10, ax = ax[0]);
#q_value in ARIMA(d,p,q)
plot_acf(df['China'], lags =10, ax = ax[1]);

# %% [markdown]
# # ARIMA Modeling and Forecasting:

# %%
arima_C = ARIMA(train['China'],order = (3,1,1))
arima_result_C = arima_C.fit()
plot_fit_and_forecast(arima_result_C, df_fc['China'], 'China')
# Out:
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
adf(df['European Union'])
# Out:
# Test-statistic: -2.4965644242784486
# p-value: 0.11631247681740836
# Non-stationary

# %%
fig,ax = plt.subplots(2,1, figsize=(8,6))
#p value in ARIMA(d,p,q)
plot_pacf(df_fc['European Union'], lags = 10, ax = ax[0]);
#q_value in ARIMA(d,p,q)
plot_acf(df_fc['European Union'], lags =10, ax = ax[1]);

# %%
arima_E = ARIMA(train['European Union'],order = (1,1,1))
arima_result_E = arima_E.fit()
plot_fit_and_forecast(arima_result_E, df_fc['European Union'], 'European Union')
# Out:
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\AppData\Local\Temp\ipykernel_14088\3914231725.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels = np.arange(1991, 2022, 1), rotation = 90)

# %%
adf(df['United States'])
# Out:
# Test-statistic: -2.304539022988513
# p-value: 0.1705082251355967
# Non-stationary

# %%
fig,ax = plt.subplots(2,1, figsize=(8,6))
#p value in ARIMA(d,p,q)
plot_pacf(df_fc['United States'], lags = 10, ax = ax[0]);
#q_value in ARIMA(d,p,q)
plot_acf(df_fc['United States'], lags =10, ax = ax[1]);

# %%
arima_U = ARIMA(train['United States'],order = (6,1,1))
arima_result_U = arima_U.fit()
plot_fit_and_forecast(arima_result_U, df_fc['United States'], 'United States')
# Out:
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
plt.figure(figsize = (300,4));

plt.figure(figsize=(20,10))
plt.subplot(2, 3, 1)
df[["Russian Federation", "Canada", "China", "United States", "Brazil", "Australia", "India", "Argentina", "Kazakhstan","Algeria"]].loc["2000"].plot(kind = 'bar')
plt.title("GDP for selected countries of the year 2000")
plt.subplot(2, 3, 3)
df[["Russian Federation", "Canada", "China", "United States", "Brazil", "Australia", "India", "Argentina", "Kazakhstan","Algeria"]].loc["2005"].plot(kind = 'bar')
plt.title("GDP for selected countries of the year 2005")

plt.subplot(2, 3, 5)
df[["Russian Federation", "Canada", "China", "United States", "Brazil", "Australia", "India", "Argentina", "Kazakhstan","Algeria"]].loc["2021"].plot(kind = 'bar')
plt.title("GDP for selected countries of the year 2021")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

years = np.arange(1991, 2022)
gdp_per_capita_India=df["India"].tolist()
gdp_per_capita_Russian_Federation=df["Russian Federation"].tolist()
gdp_per_capita_United_States=df["United States"].tolist()
gdp_per_capita_Europe_ca=df["Europe & Central Asia"].tolist()
gdp_per_capita_Ireland=df["Ireland"].tolist()

# Create a DataFrame
data_india = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_India})
data_Russian_Federation = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_Russian_Federation})
data_United_States = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_United_States})
data_Europe_ca = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_Europe_ca})
data_Ireland = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_Ireland})


future_years = np.arange(2021, 2031)
# Fit ARIMA model
#India
model_india = ARIMA(data_india['GDP_Per_Capita'], order=(1, 1, 1))  # You may need to adjust order based on your data
result_india = model_india.fit()
forecast_india = result_india.get_forecast(steps=len(future_years))# Forecast future values
confidence_intervals_india = forecast_india.conf_int()

#Russian Federation
model_Russian_Federation = ARIMA(data_Russian_Federation['GDP_Per_Capita'], order=(1, 1, 1))  # You may need to adjust order based on your data
result_Russian_Federation = model_Russian_Federation.fit()
forecast_Russian_Federation = result_Russian_Federation.get_forecast(steps=len(future_years))# Forecast future values
confidence_intervals_Russian_Federation = forecast_Russian_Federation.conf_int()

#United States
model_United_States = ARIMA(data_United_States['GDP_Per_Capita'], order=(1, 1, 1))  # You may need to adjust order based on your data
result_United_States = model_United_States.fit()
forecast_United_States = result_United_States.get_forecast(steps=len(future_years))# Forecast future values
confidence_intervals_United_States = forecast_United_States.conf_int()

#Europe and Central Asia
model_Europe_ca = ARIMA(data_Europe_ca['GDP_Per_Capita'], order=(1, 1, 1))  # You may need to adjust order based on your data
result_Europe_ca = model_Europe_ca.fit()
forecast_Europe_ca = result_Europe_ca.get_forecast(steps=len(future_years))# Forecast future values
confidence_intervals_Europe_ca = forecast_Europe_ca.conf_int()

#Ireland
model_Ireland = ARIMA(data_Ireland['GDP_Per_Capita'], order=(1, 1, 1))  # You may need to adjust order based on your data
result_Ireland = model_Ireland.fit()
forecast_Ireland = result_Ireland.get_forecast(steps=len(future_years))# Forecast future values
confidence_intervals_Ireland = forecast_Ireland.conf_int()

# Plot the results
plt.figure(figsize=(20,20))
plt.subplot(3, 2, 1)
plt.plot(data_india['Year'], data_india['GDP_Per_Capita'], marker='o', linestyle='-', color='b', label='Historical Data')
plt.plot(future_years, forecast_india.predicted_mean, color='r', label='Forecasted Values')
plt.fill_between(future_years, confidence_intervals_india['lower GDP_Per_Capita'], confidence_intervals_india['upper GDP_Per_Capita'], color='pink', alpha=0.3, label='Confidence Intervals')
plt.xlabel('Year')
plt.ylabel('GDP Per Capita')
plt.title('Forecast of India unemployement')
plt.legend(loc = 'upper left')

plt.subplot(3, 2, 2)
plt.plot(data_Russian_Federation['Year'], data_Russian_Federation['GDP_Per_Capita'], marker='o', linestyle='-', color='b', label='Historical Data')
plt.plot(future_years, forecast_Russian_Federation.predicted_mean, color='r', label='Forecasted Values')
plt.fill_between(future_years, confidence_intervals_Russian_Federation['lower GDP_Per_Capita'], confidence_intervals_Russian_Federation['upper GDP_Per_Capita'], color='pink', alpha=0.3, label='Confidence Intervals')
plt.xlabel('Year')
plt.ylabel('unemployement')
plt.title('Forecast of Russian Federation unemployement')
plt.legend(loc = 'upper left')

plt.subplot(3, 2, 3)
plt.plot(data_United_States['Year'], data_United_States['GDP_Per_Capita'], marker='o', linestyle='-', color='b', label='Historical Data')
plt.plot(future_years, forecast_United_States.predicted_mean, color='r', label='Forecasted Values')
plt.fill_between(future_years, confidence_intervals_United_States['lower GDP_Per_Capita'], confidence_intervals_United_States['upper GDP_Per_Capita'], color='pink', alpha=0.3, label='Confidence Intervals')
plt.xlabel('Year')
plt.ylabel('unemployement')
plt.title('Forecast of United States unemployement')
plt.legend(loc = 'upper left')

plt.subplot(3, 2, 4)
plt.plot(data_Europe_ca['Year'], data_Europe_ca['GDP_Per_Capita'], marker='o', linestyle='-', color='b', label='Historical Data')
plt.plot(future_years, forecast_Europe_ca.predicted_mean, color='r', label='Forecasted Values')
plt.fill_between(future_years, confidence_intervals_Europe_ca['lower GDP_Per_Capita'], confidence_intervals_Europe_ca['upper GDP_Per_Capita'], color='pink', alpha=0.3, label='Confidence Intervals')
plt.xlabel('Year')
plt.ylabel('unemployement')
plt.title('Forecast of Europe & Central Asia unemployement')
plt.legend(loc = 'upper left')

plt.subplot(3, 2, 5)
plt.plot(data_Ireland['Year'], data_Ireland['GDP_Per_Capita'], marker='o', linestyle='-', color='b', label='Historical Data')
plt.plot(future_years, forecast_Ireland.predicted_mean, color='r', label='Forecasted Values')
plt.fill_between(future_years, confidence_intervals_Ireland['lower GDP_Per_Capita'], confidence_intervals_Ireland['upper GDP_Per_Capita'], color='pink', alpha=0.3, label='Confidence Intervals')
plt.xlabel('Year')
plt.ylabel('GDP Per Capita')
plt.title('Forecast of Ireland unemployement')
plt.legend(loc = 'upper left')

plt.show()


data_india = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_India})
data_Russian_Federation = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_Russian_Federation})
data_United_States = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_United_States})
data_Europe_ca = pd.DataFrame(data={'Year': years, 'GDP_Per_Capita': gdp_per_capita_Europe_ca})


# Evaluate the model
mse_india = mean_squared_error(data_india['GDP_Per_Capita'], result_india.fittedvalues)
rmse_india = sqrt(mse_india)
print(f'Root Mean Squared Error of india model: {rmse_india}')

mse_Russian_Federation = mean_squared_error(data_Russian_Federation['GDP_Per_Capita'], result_Russian_Federation.fittedvalues)
rmse_Russian_Federation = sqrt(mse_Russian_Federation)
print(f'Root Mean Squared Error of Russian Federation model: {rmse_Russian_Federation}')

mse_United_States = mean_squared_error(data_United_States['GDP_Per_Capita'], result_United_States.fittedvalues)
rmse_United_States = sqrt(mse_United_States)
print(f'Root Mean Squared Error of United States model: {rmse_United_States}')

mse_Europe_ca = mean_squared_error(data_Europe_ca['GDP_Per_Capita'], result_Europe_ca.fittedvalues)
rmse_Europe_ca = sqrt(mse_Europe_ca)
print(f'Root Mean Squared Error of Europe & Central Asia model: {rmse_Europe_ca}')

mse_Ireland = mean_squared_error(data_Ireland['GDP_Per_Capita'], result_Ireland.fittedvalues)
rmse_Ireland = sqrt(mse_Ireland)
print(f'Root Mean Squared Error of Ireland model: {rmse_Ireland}')
# Out:
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Waqas\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Root Mean Squared Error of india model: 1.1070253625623767
# Root Mean Squared Error of Russian Federation model: 1.3777381433715328
# Root Mean Squared Error of United States model: 1.697916699291699
# ...
